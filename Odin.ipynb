# %%
import pandas as pd

df = pd.read_csv("car_data.csv")

df.head()
# Out:
#                                             Car_Name        Make       Model  \
# 0   Volkswagen Ameo [2016-2017] Highline 1.5L AT (D)  Volkswagen        Ameo
# 1              Hyundai i20 Active [2015-2020] 1.2 SX     Hyundai  i20 Active
# 2                               Honda WR-V VX i-VTEC       Honda        WR-V
# 3                           Renault Kwid 1.0 RXT AMT     Renault        Kwid
# 4  Hyundai Grand i10 [2017-2020] Asta 1.2 Kappa VTVT     Hyundai   Grand i10
#
#    Make_Year   Color  Body_Type Mileage_Run No_of_Owners  Seating_Capacity  \
# 0       2017  silver      sedan      44,611          1st                 5
# 1       2016     red  crossover      20,305          1st                 5
# 2       2019   white        suv      29,540          2nd                 5
# 3       2017  bronze  hatchback      35,680          1st                 5
# 4       2017  orange  hatchback      25,126          1st                 5
#
# ...

# %%
df.tail()
# Out:
#                                              Car_Name           Make  \
# 971             Hyundai Verna [2017-2020] 1.6 VTVT SX        Hyundai
# 972             Hyundai Verna [2017-2020] 1.6 VTVT SX        Hyundai
# 973  Hyundai Verna [2011-2015] Fluidic 1.6 VTVT SX AT        Hyundai
# 974   Ford Freestyle [2020-2021] Flair Edition Diesel           Ford
# 975  Maruti Suzuki Ignis [2017-2020] Alpha AMT Petrol  Maruti Suzuki
#
#          Model  Make_Year   Color  Body_Type Mileage_Run No_of_Owners  \
# 971      Verna       2018   white      sedan      23,869          1st
# 972      Verna       2019   white      sedan      14,831          1st
# 973      Verna       2014  silver      sedan      52,846          1st
# 974  Freestyle       2020   white  crossover      28,335          2nd
# 975      Ignis       2018  silver  hatchback      41,176          1st
#
#      Seating_Capacity Fuel_Type  Fuel_Tank_Capacity(L)  \
# 971                 5    petrol                     43
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 976 entries, 0 to 975
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Car_Name               976 non-null    object
#  1   Make                   976 non-null    object
#  2   Model                  976 non-null    object
#  3   Make_Year              976 non-null    int64
#  4   Color                  976 non-null    object
#  5   Body_Type              976 non-null    object
#  6   Mileage_Run            976 non-null    object
#  7   No_of_Owners           976 non-null    object
#  8   Seating_Capacity       976 non-null    int64
#  9   Fuel_Type              976 non-null    object
#  10  Fuel_Tank_Capacity(L)  976 non-null    int64
#  11  Engine_Type            976 non-null    object
#  12  CC_Displacement        976 non-null    int64
#  13  Transmission           976 non-null    object
# ...

# %%
df.head()
# Out:
#                                             Car_Name        Make       Model  \
# 0   Volkswagen Ameo [2016-2017] Highline 1.5L AT (D)  Volkswagen        Ameo
# 1              Hyundai i20 Active [2015-2020] 1.2 SX     Hyundai  i20 Active
# 2                               Honda WR-V VX i-VTEC       Honda        WR-V
# 3                           Renault Kwid 1.0 RXT AMT     Renault        Kwid
# 4  Hyundai Grand i10 [2017-2020] Asta 1.2 Kappa VTVT     Hyundai   Grand i10
#
#    Make_Year   Color  Body_Type Mileage_Run No_of_Owners  Seating_Capacity  \
# 0       2017  silver      sedan      44,611          1st                 5
# 1       2016     red  crossover      20,305          1st                 5
# 2       2019   white        suv      29,540          2nd                 5
# 3       2017  bronze  hatchback      35,680          1st                 5
# 4       2017  orange  hatchback      25,126          1st                 5
#
# ...

# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplpy as plt
#Removing commas in Price Column
df['Price']=df['Price'].str.replace(',','')

#Converting Price currency from Indian Rupees to US Dollars
df['Price'] = pd.to_numeric(df['Price'])
df.loc[:, 'Price'] *= 0.012

#Converting No. Owners from String description to int
df['No_of_Owners']=df['No_of_Owners'].str.replace('1st', "1")
df['No_of_Owners']=df['No_of_Owners'].str.replace('2nd', "2")
df['No_of_Owners']=df['No_of_Owners'].str.replace('3rd', "3")
df['No_of_Owners'] = pd.to_numeric(df['No_of_Owners'])

df = df.rename(columns = {"Fuel_Tank_Capacity(L)" : "Fuel_Tank_Capacity(G)"})
df.loc[:, 'Fuel_Tank_Capacity(G)'] /= 3.785

df.head()


#fig = px.histogram(df, x="Price")
#fig.show()

#x = df[["Make", "Make_Year", "Price"]]
#fig = px.scatter_matrix(x, color = "Make")
#fig = px.scatter(df, x = "Price", y = "No_of_Owners")
#fig.show()
# Out:
# /tmp/ipykernel_1080674/2559083344.py:8: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#                                             Car_Name        Make       Model  \
# 0   Volkswagen Ameo [2016-2017] Highline 1.5L AT (D)  Volkswagen        Ameo
# 1              Hyundai i20 Active [2015-2020] 1.2 SX     Hyundai  i20 Active
# 2                               Honda WR-V VX i-VTEC       Honda        WR-V
# 3                           Renault Kwid 1.0 RXT AMT     Renault        Kwid
# 4  Hyundai Grand i10 [2017-2020] Asta 1.2 Kappa VTVT     Hyundai   Grand i10
#
#    Make_Year   Color  Body_Type Mileage_Run  No_of_Owners  Seating_Capacity  \
# 0       2017  silver      sedan      44,611             1                 5
# ...

# %%
fig = px.histogram(df, x="Price")
fig.show()
# Mean price range: 5000 - 5999 - 120 cars in that range 

#fig = px.histogram(df, x="Price", histnorm="No_of_Owners" )
#fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="Price", color ="No_of_Owners" )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
f = px.histogram(df, x = "Price", color = "Make_Year")
f.show()
print("Most expensive cars have been made within the last 3 years")

#DX = px.data.tips()
#fig = px.histogram(df, x="Price", y="No_of_Owners", histfunc="avg")
#fig.show()
#-----
#fig = px.histogram(df, x="Price", y="No_of_Owners")
#fig.show()
#category_orders=dict(day=["5k", "7k", "10K", "12k", "15k"]),
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x = [1, 2, 3, 4]
y = [10, 15, 20, 25]

fig, ax = plt.subplots()
ax.plot(x, y)
plt.ylim(0, 30)
plt.show()

# %%
x = df[["Make" , "Price"]]

fig = px.scatter_matrix(x)
fig.show()
# Out:
# /projects/f9a25c35-74a4-42eb-85d0-6758c9231670/miniconda3/lib/python3.10/site-packages/plotly/express/_core.py:279: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x="Price", y = "Make", color ="No_of_Owners" )
fig.show()
#takes sum of prices for each make, this does not account for how many makes there are, per brand.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#counts = df["Make"].str.count('Hyundai')
#count_counts = counts.value_counts()
#counts_counts.show()
#print(df["Make"].value_counts()["Hyundai"])

print(df["Make"].value_counts()["Kia"])
# Out:
# 8
